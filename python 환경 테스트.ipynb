# %% [markdown]
# ## 주피터 노트북 확인

# %%
1+1
# Out:
# 2

# %%
x = 3
x
# Out:
# 3

# %%
2+4
# Out:
# 6

# %%
print("Hello, Python")
# Out:
# Hello, Python

# %% [markdown]
# ## Interactive matplotlib 환경 테스트

# %%
import matplotlib

# %%
# matplotlib jupyter 매직 명령어를 실행하여 `widget` 벡엔드를 활성화
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([5,6])
plt.title('test')
# Out:
# Text(0.5, 1.0, 'test')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.title('test2')
# Out:
# Text(0.5, 1.0, 'test2')

# %%
# Testing matplotlib interactions with a simple plot
fig = plt.figure()
plt.plot(np.sin(np.linspace(0, 20, 100)));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 딥러닝 패키지 keras 환경 테스트

# %%
import keras

# %% [markdown]
# ## 음악 및 오디오 분석을 위한 Librosa 라이브러리 환경 테스트

# %%
import librosa

# %% [markdown]
# ## 시스템 정보 출력용 watermark 설치 확인

# %%
import watermark
import matplotlib

# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2022-03-14T19:37:16.745915+09:00
#
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 8.0.1
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit

# %%
# %watermark  -iv
# Out:
# librosa   : 0.9.1
# numpy     : 1.21.5
# matplotlib: 3.5.1
# keras     : 2.4.3
# watermark : 2.3.0

# %% [markdown]
# ## 데이터 분석을 위한 Pandas 라이브러리 확인

# %%
import pandas as pd

# %% [markdown]
# ## 이미지 입출력을 위한 imageio 라이브러리 확인

# %%
import imageio

# %% [markdown]
# ## 시각화를 위한 Seaborn 라이브러리 확인

# %%
import seaborn
